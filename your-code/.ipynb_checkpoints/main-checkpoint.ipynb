# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np

sns.set()
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
sales_item_type = data.groupby('ItemType').agg({'RetailSales':'sum','RetailTransfers':'sum','WarehouseSales':'sum'})

#sales = sales_item_type.set_index('ItemType')

retailSales = sales_item_type['RetailSales']
retailTransfers=sales_item_type['RetailTransfers']
warehouseSales=sales_item_type['WarehouseSales']

fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# RetailSales
a = sns.barplot(ax=axes[0], x=retailSales.index, y=retailSales.values)
axes[0].set_title(RetailSales.name)
a.set_xticklabels(rotation=90,labels=RetailSales.index)

# RetailTransfers
b=sns.barplot(ax=axes[1], x=retailTransfers.index, y=retailTransfers.values)
axes[1].set_title(RetailTransfers.name)
b.set_xticklabels(rotation=90,labels=RetailTransfers.index)

# WarehouseSales
c=sns.barplot(ax=axes[2], x=warehouseSales.index, y=warehouseSales.values)
axes[2].set_title(WarehouseSales.name)
c.set_xticklabels(rotation=90,labels=WarehouseSales.index);

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data.head(2)
data['TotalSales']=data['RetailSales']+data['RetailTransfers']+data['WarehouseSales']
top10 = data.groupby('Supplier').agg({'TotalSales':'sum'})
top10 = top10.nlargest(10,'TotalSales').reset_index(drop=True).sort_values('TotalSales',ascending=True)

top10.plot.barh(figsize=(8, 10), color='black', width=.8,alpha=.6);

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data.head()
average = data.groupby('Month').agg({'RetailSales':'mean','RetailTransfers':'mean','WarehouseSales':'mean'})
average

plt.plot(average.index, 'RetailSales', data=average, color='blue', linewidth=2)
plt.plot(average.index, 'RetailTransfers', data=average, color='red', linewidth=2)
plt.plot(average.index, 'WarehouseSales', data=average, color='purple', linewidth=2)
plt.legend();

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
barwidth =.25
height1=average['RetailSales']
height2=average['RetailTransfers']
height3=average['WarehouseSales']

r1 = np.arange(len(height1))
r2 = [x + barwidth for x in r1]
r3 = [x + barwidth for x in r2]


plt.bar(r1, height1, color='purple', width=barwidth, edgecolor='white', label='RetailSales')
plt.bar(r2, height2, color='green', width=barwidth, edgecolor='white', label='RetailTransfers')
plt.bar(r3, height3, color='blue', width=barwidth, edgecolor='white', label='WarehouseSalesar')

plt.legend()
plt.show();
average
# Out:
#        RetailSales  RetailTransfers  WarehouseSales
# Month
# 1         5.679413         5.574833       19.072137
# 2         5.939247         6.050136       20.229658
# 4         0.000000        15.707503        0.000000
# 5         7.038838         7.421817       27.310548
# 6         7.143914         6.950396       27.839069
# 8         6.409991         6.584726       28.122641
# 9         6.757254         6.419721       22.817909
# 10        6.549021         6.827827       22.289367
# 11        6.765496         7.103699       23.348862
# 12        9.078241         8.353759       21.169463

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
total_sales = data.pivot_table(values = 'RetailSales', columns = 'ItemType', index = ['Year', 'Month'], aggfunc = sum)
total_sales.plot(figsize = (20,8));

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
total_sales.plot.bar(figsize = (20,8));

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.scatterplot(data=data,x='RetailSales',y='RetailTransfers',hue='ItemType');

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Month', ylabel='Year'>,
#         <AxesSubplot:xlabel='RetailSales', ylabel='Year'>,
#         <AxesSubplot:xlabel='RetailTransfers', ylabel='Year'>,
#         <AxesSubplot:xlabel='WarehouseSales', ylabel='Year'>,
#         <AxesSubplot:xlabel='TotalSales', ylabel='Year'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Month'>,
#         <AxesSubplot:xlabel='Month', ylabel='Month'>,
#         <AxesSubplot:xlabel='RetailSales', ylabel='Month'>,
#         <AxesSubplot:xlabel='RetailTransfers', ylabel='Month'>,
#         <AxesSubplot:xlabel='WarehouseSales', ylabel='Month'>,
#         <AxesSubplot:xlabel='TotalSales', ylabel='Month'>],
#        [<AxesSubplot:xlabel='Year', ylabel='RetailSales'>,
#         <AxesSubplot:xlabel='Month', ylabel='RetailSales'>,
#         <AxesSubplot:xlabel='RetailSales', ylabel='RetailSales'>,
#         <AxesSubplot:xlabel='RetailTransfers', ylabel='RetailSales'>,
#         <AxesSubplot:xlabel='WarehouseSales', ylabel='RetailSales'>,
#         <AxesSubplot:xlabel='TotalSales', ylabel='RetailSales'>],
#        [<AxesSubplot:xlabel='Year', ylabel='RetailTransfers'>,
#         <AxesSubplot:xlabel='Month', ylabel='RetailTransfers'>,
#         <AxesSubplot:xlabel='RetailSales', ylabel='RetailTransfers'>,
#         <AxesSubplot:xlabel='RetailTransfers', ylabel='RetailTransfers'>,
#         <AxesSubplot:xlabel='WarehouseSales', ylabel='RetailTransfers'>,
#         <AxesSubplot:xlabel='TotalSales', ylabel='RetailTransfers'>],
#        [<AxesSubplot:xlabel='Year', ylabel='WarehouseSales'>,
#         <AxesSubplot:xlabel='Month', ylabel='WarehouseSales'>,
#         <AxesSubplot:xlabel='RetailSales', ylabel='WarehouseSales'>,
#         <AxesSubplot:xlabel='RetailTransfers', ylabel='WarehouseSales'>,
#         <AxesSubplot:xlabel='WarehouseSales', ylabel='WarehouseSales'>,
#         <AxesSubplot:xlabel='TotalSales', ylabel='WarehouseSales'>],
#        [<AxesSubplot:xlabel='Year', ylabel='TotalSales'>,
#         <AxesSubplot:xlabel='Month', ylabel='TotalSales'>,
#         <AxesSubplot:xlabel='RetailSales', ylabel='TotalSales'>,
#         <AxesSubplot:xlabel='RetailTransfers', ylabel='TotalSales'>,
#         <AxesSubplot:xlabel='WarehouseSales', ylabel='TotalSales'>,
#         <AxesSubplot:xlabel='TotalSales', ylabel='TotalSales'>]],
#       dtype=object)
